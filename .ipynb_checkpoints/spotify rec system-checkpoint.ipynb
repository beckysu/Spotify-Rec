# %%
import csv
import os
import re
import pandas as pd
import json
import spotipy
from tqdm import tqdm
from spotipy.oauth2 import SpotifyClientCredentials
from dotenv import load_dotenv
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Connect to API

# %%
# load credentials from .env file
load_dotenv()

CLIENT_ID = os.getenv("CLIENT_ID", "")
CLIENT_SECRET = os.getenv("CLIENT_SECRET", "")
OUTPUT_FILE_NAME = "lukewarm_playlist.csv"

# change for your target playlist
playlist_link = "https://open.spotify.com/playlist/3W0kChA5K4tozflcfjFmzv?si=4b50754f3f914f9e"

# %%
# authenticate
client_credentials_manager = SpotifyClientCredentials(
    client_id=CLIENT_ID, client_secret=CLIENT_SECRET
)

# create spotify session object
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %% [markdown]
# ## Extract Playlist Data

# %%
# get playlist uri from https link
playlist_uri = playlist_link.split("/")[-1].split("?")[0]

# %%
def get_playlist_tracks(playlist_uri):
    results =  sp.playlist_tracks(playlist_uri)
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks

# %%
df = pd.DataFrame(columns=["track_uri","track_name","track_pop",
                           "artist_uri","artist_info", "artist_name", 
                           "artist_pop", "artist_genres", "album_name"])

# %%
# extract relevant column details from json data
for track in get_playlist_tracks(playlist_uri): 
    track_uri = track['track']['uri']
    track_name = track['track']['name']
    artist_uri = track['track']['artists'][0]['uri']
    artist_info = sp.artist(artist_uri)
    artist_name = track['track']['artists'][0]['name']
    artist_pop = artist_info['popularity']
    artist_genres = artist_info['genres']
    album_name = track['track']['album']['name']
    track_pop = track['track']['popularity']
    
    df = df.append({'track_uri':track_uri,'track_name':track_name, 'track_pop':track_pop,
                'artist_uri':artist_uri,'artist_info':artist_info, 'artist_name':artist_name, 
                'artist_pop':artist_pop, 'artist_genres':artist_genres, 'album_name':album_name},ignore_index=True)

# %%
df.head()
# Out:
#                               track_uri  \
# 0  spotify:track:5awvelCGpDQHwgZem0ira9
# 1  spotify:track:44uCMdE6RWnkOFYTtbmUUc
# 2  spotify:track:6vl5ghDnotGACfQy6JDYzY
# 3  spotify:track:0rWXN4PLsnNaWDelk2938S
# 4  spotify:track:3ZNOdspGb2cdossfsUqTjw
#
#                                           track_name track_pop  \
# 0                                             Lately        53
# 1                                        Cherry Cola        56
# 2  A Song to Sing (feat. Mark Battles & Devvon Te...         0
# 3                                                NWA         0
# 4                                         Just Chill        35
#
#                               artist_uri  \
# 0  spotify:artist:6chWbUfdu6ibyaCXM1w8kQ
# 1  spotify:artist:66LFdGYtbmJ6G8sArrkfsu
# 2  spotify:artist:5vGXVYudNgm9E7jhXMM0Ro
# 3  spotify:artist:0gKR8NI5vgeG9kCyt8q06v
# 4  spotify:artist:6chWbUfdu6ibyaCXM1w8kQ
#
#                                          artist_info artist_name artist_pop  \
# 0  {'external_urls': {'spotify': 'https://open.sp...    Forrest.         58
# 1  {'external_urls': {'spotify': 'https://open.sp...      Kuwada         47
# 2  {'external_urls': {'spotify': 'https://open.sp...   Kid Quill         51
# 3  {'external_urls': {'spotify': 'https://open.sp...        Ryce         46
# 4  {'external_urls': {'spotify': 'https://open.sp...    Forrest.         58
#
#                                     artist_genres                album_name
# 0                                     [lo-fi rap]                    Lately
# 1                                              []               Cherry Cola
# 2  [indiana hip hop, indie pop rap, pop, pop rap]  The Name Above the Title
# 3                                     [lo-fi rap]                       NWA
# 4                                     [lo-fi rap]                      Warm

# %%
#df.to_csv('playlist_raw.csv')

# %% [markdown]
# ## Extract Track Features

# %%
sp.audio_features(df['track_uri'][0])
# Out:
# [{'danceability': 0.718,
#   'energy': 0.632,
#   'key': 0,
#   'loudness': -4.011,
#   'mode': 1,
#   'speechiness': 0.145,
#   'acousticness': 0.213,
#   'instrumentalness': 1.28e-05,
#   'liveness': 0.283,
#   'valence': 0.859,
#   'tempo': 160.039,
#   'type': 'audio_features',
#   'id': '5awvelCGpDQHwgZem0ira9',
#   'uri': 'spotify:track:5awvelCGpDQHwgZem0ira9',
#   'track_href': 'https://api.spotify.com/v1/tracks/5awvelCGpDQHwgZem0ira9',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5awvelCGpDQHwgZem0ira9',
#   'duration_ms': 207000,
#   'time_signature': 4}]

# %%
#Edit the track-uris to a more usable format
df["track_uri"] = df["track_uri"].apply(lambda x: re.findall(r'\w+$', x)[0])
df["track_uri"]
# Out:
# 0      5awvelCGpDQHwgZem0ira9
# 1      44uCMdE6RWnkOFYTtbmUUc
# 2      6vl5ghDnotGACfQy6JDYzY
# 3      0rWXN4PLsnNaWDelk2938S
# 4      3ZNOdspGb2cdossfsUqTjw
#                 ...
# 586    3jgTthrOsgFR1477mor7Ex
# 587    4AwJSk491AvHk2AAJReGzZ
# 588    3UnfOb5hmnf4KF7NIgAj9a
# 589    1fiSki9Yy5lekUUpV4mByo
# 590    2d3QlXE6FXFDeodiS66yjM
# Name: track_uri, Length: 591, dtype: object

# %%
features = df['track_uri'].unique()

# %%
feature_data = []

for i in tqdm([uri for uri in features]):
    try:
        feature_data.append(sp.audio_features(i))
    except:
        continue
# Out:
# 100%|██████████| 591/591 [00:55<00:00, 10.57it/s]

# %%
feature_df = pd.DataFrame.from_dict(feature_data)
feature_df = pd.json_normalize(feature_df[0])
feature_df.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.718   0.632    0    -4.011     1       0.1450       0.21300
# 1         0.777   0.635    5    -6.323     0       0.0392       0.76400
# 2         0.745   0.741    2    -7.212     1       0.1840       0.20900
# 3         0.829   0.543    7    -6.886     1       0.0486       0.39000
# 4         0.700   0.530    4    -6.216     1       0.0285       0.00775
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0          0.000013    0.2830    0.859  160.039  audio_features
# 1          0.000002    0.1550    0.653  138.040  audio_features
# 2          0.000000    0.5100    0.480   94.002  audio_features
# 3          0.156000    0.0988    0.358  101.027  audio_features
# 4          0.000894    0.1950    0.505   99.992  audio_features
#
#                        id                                   uri  \
# 0  5awvelCGpDQHwgZem0ira9  spotify:track:5awvelCGpDQHwgZem0ira9
# 1  44uCMdE6RWnkOFYTtbmUUc  spotify:track:44uCMdE6RWnkOFYTtbmUUc
# 2  6vl5ghDnotGACfQy6JDYzY  spotify:track:6vl5ghDnotGACfQy6JDYzY
# 3  0rWXN4PLsnNaWDelk2938S  spotify:track:0rWXN4PLsnNaWDelk2938S
# 4  3ZNOdspGb2cdossfsUqTjw  spotify:track:3ZNOdspGb2cdossfsUqTjw
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/5awvelCGpDQH...
# 1  https://api.spotify.com/v1/tracks/44uCMdE6RWnk...
# 2  https://api.spotify.com/v1/tracks/6vl5ghDnotGA...
# 3  https://api.spotify.com/v1/tracks/0rWXN4PLsnNa...
# 4  https://api.spotify.com/v1/tracks/3ZNOdspGb2cd...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/5awv...       207000
# 1  https://api.spotify.com/v1/audio-analysis/44uC...       184360
# 2  https://api.spotify.com/v1/audio-analysis/6vl5...       185487
# 3  https://api.spotify.com/v1/audio-analysis/0rWX...        83156
# 4  https://api.spotify.com/v1/audio-analysis/3ZNO...       220482
#
#    time_signature
# 0               4
# 1               4
# 2               4
# 3               4
# 4               4

# %%
#feature_df.to_csv('playlist_features.csv')

# %%
feature_df = feature_df.rename(columns={'uri': 'track_uri'})
feature_df["track_uri"] = feature_df["track_uri"].apply(lambda x: re.findall(r'\w+$', x)[0])
feature_df["track_uri"]
# Out:
# 0      5awvelCGpDQHwgZem0ira9
# 1      44uCMdE6RWnkOFYTtbmUUc
# 2      6vl5ghDnotGACfQy6JDYzY
# 3      0rWXN4PLsnNaWDelk2938S
# 4      3ZNOdspGb2cdossfsUqTjw
#                 ...
# 586    3jgTthrOsgFR1477mor7Ex
# 587    4AwJSk491AvHk2AAJReGzZ
# 588    3UnfOb5hmnf4KF7NIgAj9a
# 589    1fiSki9Yy5lekUUpV4mByo
# 590    2d3QlXE6FXFDeodiS66yjM
# Name: track_uri, Length: 591, dtype: object

# %%
# merge df and feature_df dataframes
fulldf = pd.merge(df, feature_df, on='track_uri')

# %%
fulldf.head()
# Out:
#                 track_uri                                         track_name  \
# 0  5awvelCGpDQHwgZem0ira9                                             Lately
# 1  44uCMdE6RWnkOFYTtbmUUc                                        Cherry Cola
# 2  6vl5ghDnotGACfQy6JDYzY  A Song to Sing (feat. Mark Battles & Devvon Te...
# 3  0rWXN4PLsnNaWDelk2938S                                                NWA
# 4  3ZNOdspGb2cdossfsUqTjw                                         Just Chill
#
#   track_pop                             artist_uri  \
# 0        53  spotify:artist:6chWbUfdu6ibyaCXM1w8kQ
# 1        56  spotify:artist:66LFdGYtbmJ6G8sArrkfsu
# 2         0  spotify:artist:5vGXVYudNgm9E7jhXMM0Ro
# 3         0  spotify:artist:0gKR8NI5vgeG9kCyt8q06v
# 4        35  spotify:artist:6chWbUfdu6ibyaCXM1w8kQ
#
#                                          artist_info artist_name artist_pop  \
# 0  {'external_urls': {'spotify': 'https://open.sp...    Forrest.         58
# 1  {'external_urls': {'spotify': 'https://open.sp...      Kuwada         47
# 2  {'external_urls': {'spotify': 'https://open.sp...   Kid Quill         51
# 3  {'external_urls': {'spotify': 'https://open.sp...        Ryce         46
# 4  {'external_urls': {'spotify': 'https://open.sp...    Forrest.         58
#
#                                     artist_genres                album_name  \
# 0                                     [lo-fi rap]                    Lately
# 1                                              []               Cherry Cola
# 2  [indiana hip hop, indie pop rap, pop, pop rap]  The Name Above the Title
# 3                                     [lo-fi rap]                       NWA
# 4                                     [lo-fi rap]                      Warm
#
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.718   0.632    0    -4.011     1       0.1450       0.21300
# 1         0.777   0.635    5    -6.323     0       0.0392       0.76400
# 2         0.745   0.741    2    -7.212     1       0.1840       0.20900
# 3         0.829   0.543    7    -6.886     1       0.0486       0.39000
# 4         0.700   0.530    4    -6.216     1       0.0285       0.00775
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0          0.000013    0.2830    0.859  160.039  audio_features
# 1          0.000002    0.1550    0.653  138.040  audio_features
# 2          0.000000    0.5100    0.480   94.002  audio_features
# 3          0.156000    0.0988    0.358  101.027  audio_features
# 4          0.000894    0.1950    0.505   99.992  audio_features
#
#                        id                                         track_href  \
# 0  5awvelCGpDQHwgZem0ira9  https://api.spotify.com/v1/tracks/5awvelCGpDQH...
# 1  44uCMdE6RWnkOFYTtbmUUc  https://api.spotify.com/v1/tracks/44uCMdE6RWnk...
# 2  6vl5ghDnotGACfQy6JDYzY  https://api.spotify.com/v1/tracks/6vl5ghDnotGA...
# 3  0rWXN4PLsnNaWDelk2938S  https://api.spotify.com/v1/tracks/0rWXN4PLsnNa...
# 4  3ZNOdspGb2cdossfsUqTjw  https://api.spotify.com/v1/tracks/3ZNOdspGb2cd...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/5awv...       207000
# 1  https://api.spotify.com/v1/audio-analysis/44uC...       184360
# 2  https://api.spotify.com/v1/audio-analysis/6vl5...       185487
# 3  https://api.spotify.com/v1/audio-analysis/0rWX...        83156
# 4  https://api.spotify.com/v1/audio-analysis/3ZNO...       220482
#
#    time_signature
# 0               4
# 1               4
# 2               4
# 3               4
# 4               4

# %% [markdown]
# # Exploratory Data Analysis

# %%
# cleaning data
fulldf["artist_uri"] = fulldf["artist_uri"].apply(lambda x: re.findall(r'\w+$', x)[0])
fulldf["artist_uri"]
# Out:
# 0      6chWbUfdu6ibyaCXM1w8kQ
# 1      66LFdGYtbmJ6G8sArrkfsu
# 2      5vGXVYudNgm9E7jhXMM0Ro
# 3      0gKR8NI5vgeG9kCyt8q06v
# 4      6chWbUfdu6ibyaCXM1w8kQ
#                 ...
# 586    7zkwepHPyac6tCYl0fL0co
# 587    20wkVLutqVOYrc0kxFs7rA
# 588    1tM4ox3QsSpl3R2VwLjJ47
# 589    164Uj4eKjl6zTBKfJLFKKK
# 590    7o96HO2zrujyATtVsqGhh3
# Name: artist_uri, Length: 591, dtype: object

# %%
# checking for null/na values in fulldf dataframe
fulldf.isna().sum()
# Out:
# track_uri           0
# track_name          0
# track_pop           0
# artist_uri          0
# artist_info         0
# artist_name         0
# artist_pop          0
# artist_genres       0
# album_name          0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# type                0
# id                  0
# track_href          0
# analysis_url        0
# duration_ms         0
# time_signature      0
# dtype: int64

# %%
fulldf.columns.values
# Out:
# array(['track_uri', 'track_name', 'track_pop', 'artist_uri',
#        'artist_info', 'artist_name', 'artist_pop', 'artist_genres',
#        'album_name', 'danceability', 'energy', 'key', 'loudness', 'mode',
#        'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'type', 'id', 'track_href', 'analysis_url',
#        'duration_ms', 'time_signature'], dtype=object)

# %%
df_sub = fulldf[['artist_name','id','track_name','danceability', 'energy', 
             'key', 'loudness', 'mode', 'speechiness', 'acousticness', 
             'instrumentalness', 'liveness', 'valence', 'tempo', 
             "artist_pop", "artist_genres", "track_pop"]]

# %%
fulldf.dtypes
# Out:
# track_uri            object
# track_name           object
# track_pop            object
# artist_uri           object
# artist_info          object
# artist_name          object
# artist_pop           object
# artist_genres        object
# album_name           object
# danceability        float64
# energy              float64
# key                   int64
# loudness            float64
# mode                  int64
# speechiness         float64
# acousticness        float64
# instrumentalness    float64
# liveness            float64
# valence             float64
# tempo               float64
# type                 object
# id                   object
# track_href           object
# analysis_url         object
# duration_ms           int64
# time_signature        int64
# dtype: object

# %%
fulldf['track_pop'] = fulldf['track_pop'].astype(str).astype(int)
fulldf['artist_pop'] = fulldf['artist_pop'].astype(str).astype(int)

# %%
fulldf['track_pop'].dtype
# Out:
# dtype('int64')

# %%
df = fulldf[['track_name','artist_name','id', 'artist_genres',
             'album_name','danceability','energy', 'key', 'loudness', 
             'mode','speechiness', 'acousticness', 'instrumentalness',
             'liveness', 'valence', 'tempo', 'artist_pop', 'track_pop',
             'duration_ms', 'time_signature']]
df.head()
# Out:
#                                           track_name artist_name  \
# 0                                             Lately    Forrest.
# 1                                        Cherry Cola      Kuwada
# 2  A Song to Sing (feat. Mark Battles & Devvon Te...   Kid Quill
# 3                                                NWA        Ryce
# 4                                         Just Chill    Forrest.
#
#                        id                                   artist_genres  \
# 0  5awvelCGpDQHwgZem0ira9                                     [lo-fi rap]
# 1  44uCMdE6RWnkOFYTtbmUUc                                              []
# 2  6vl5ghDnotGACfQy6JDYzY  [indiana hip hop, indie pop rap, pop, pop rap]
# 3  0rWXN4PLsnNaWDelk2938S                                     [lo-fi rap]
# 4  3ZNOdspGb2cdossfsUqTjw                                     [lo-fi rap]
#
#                  album_name  danceability  energy  key  loudness  mode  \
# 0                    Lately         0.718   0.632    0    -4.011     1
# 1               Cherry Cola         0.777   0.635    5    -6.323     0
# 2  The Name Above the Title         0.745   0.741    2    -7.212     1
# 3                       NWA         0.829   0.543    7    -6.886     1
# 4                      Warm         0.700   0.530    4    -6.216     1
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0       0.1450       0.21300          0.000013    0.2830    0.859  160.039
# 1       0.0392       0.76400          0.000002    0.1550    0.653  138.040
# 2       0.1840       0.20900          0.000000    0.5100    0.480   94.002
# 3       0.0486       0.39000          0.156000    0.0988    0.358  101.027
# 4       0.0285       0.00775          0.000894    0.1950    0.505   99.992
#
#    artist_pop  track_pop  duration_ms  time_signature
# 0          58         53       207000               4
# 1          47         56       184360               4
# 2          51          0       185487               4
# 3          46          0        83156               4
# 4          58         35       220482               4

# %%
#converting list to str for genre column
df['genres'] = df['artist_genres'].apply(', '.join)
# Out:
# /Users/beckysu/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df = df[['track_name','artist_name','id', 'genres',
             'album_name','danceability','energy', 'key', 'loudness', 
             'mode','speechiness', 'acousticness', 'instrumentalness',
             'liveness', 'valence', 'tempo', 'artist_pop', 'track_pop',
             'duration_ms', 'time_signature']]
df.head()
# Out:
#                                           track_name artist_name  \
# 0                                             Lately    Forrest.
# 1                                        Cherry Cola      Kuwada
# 2  A Song to Sing (feat. Mark Battles & Devvon Te...   Kid Quill
# 3                                                NWA        Ryce
# 4                                         Just Chill    Forrest.
#
#                        id                                        genres  \
# 0  5awvelCGpDQHwgZem0ira9                                     lo-fi rap
# 1  44uCMdE6RWnkOFYTtbmUUc
# 2  6vl5ghDnotGACfQy6JDYzY  indiana hip hop, indie pop rap, pop, pop rap
# 3  0rWXN4PLsnNaWDelk2938S                                     lo-fi rap
# 4  3ZNOdspGb2cdossfsUqTjw                                     lo-fi rap
#
#                  album_name  danceability  energy  key  loudness  mode  \
# 0                    Lately         0.718   0.632    0    -4.011     1
# 1               Cherry Cola         0.777   0.635    5    -6.323     0
# 2  The Name Above the Title         0.745   0.741    2    -7.212     1
# 3                       NWA         0.829   0.543    7    -6.886     1
# 4                      Warm         0.700   0.530    4    -6.216     1
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0       0.1450       0.21300          0.000013    0.2830    0.859  160.039
# 1       0.0392       0.76400          0.000002    0.1550    0.653  138.040
# 2       0.1840       0.20900          0.000000    0.5100    0.480   94.002
# 3       0.0486       0.39000          0.156000    0.0988    0.358  101.027
# 4       0.0285       0.00775          0.000894    0.1950    0.505   99.992
#
#    artist_pop  track_pop  duration_ms  time_signature
# 0          58         53       207000               4
# 1          47         56       184360               4
# 2          51          0       185487               4
# 3          46          0        83156               4
# 4          58         35       220482               4

# %% [markdown]
# ## Missing Values

# %%
#sum of empty cells (non null)
(df['genres'].values == '').sum()   
#fill with na
df = df.mask(df == '')
# Out:
# /Users/beckysu/opt/anaconda3/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:253: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   res_values = method(rvalues)

# %%
df[df['genres'].isnull()]
# Out:
#                                             track_name       artist_name  \
# 1                                          Cherry Cola            Kuwada
# 7                                            Sunkissed            NVTHVN
# 8                                               Ocean~            Kuwada
# 10                               Don't Lose Your Faith    William Bolton
# 15                                            Over You    William Bolton
# 19                                              Fuck U            NVTHVN
# 28                      Satisfied (feat. Travis Mills)    William Bolton
# 29                                 Can't Afford It All            Jakubi
# 34                                        Couch Potato            Jakubi
# 39                                              Pillow            Jakubi
# 42                            Dance in the Living Room            NVTHVN
# 54                         Who's Got You Singing Again              PREP
# 93                                           Starlight            Kuwada
# 98                       불과 얼음 사이 (feat. Hovi, DJ TOM)             Aimer
# 106                               Breathing Underwater              JIAN
# 128                                           B.O.M.O.   Tatiana Manaois
# 164                                               Iroh              Sonn
# 195                                        Runaway Man   Olivia Willhite
# 221                                              I did            Chobin
# 262                                           dramatic     Cat & Calmell
# 277                               I Know I Should Call    Jennifer Chung
# 294                                        WasteUrTime     Kevin Walkman
# 315                                          Real Deal    Maths Time Joy
# 317                                       Bursley Girl         Moodswing
# 323                                            On Lock        MONEYPHONE
# 338                                 Endlessly+Tenderly   PARADISE RISING
# 364                                        Lay It Down           Steelix
# 367                                           Far Away             EASHA
# 373                                               slip             anees
# 398                  I Don't Mind (feat. Ben Chandler)       Tobias Dray
# 406                                       Be My Remedy      HOUSE OF SAY
# 411                       Favorite Colors (feat. Kyle)     Luke Tennyson
# 422                                    Time Goes "Bye"        Jex Nwalor
# 428                                            No Lies  Calvin Davis Jr.
# 441                            Shut up My Moms Calling        Hotel Ugly
# 442                                           PINCH ME      young friend
# 454                                              Pills       asiatic.wav
# 478                            ghost town (voice memo)      Chloe George
# 481                                          On My Way       Yatta Bandz
# 486                                         Slide Thru             Mills
# 491                                      Oxford Circus              Frex
# 500                                         Love Birds              wimp
# 502                                               IRIS    Ashes To Amber
# 509                                       Becky's Plan          CODY JON
# 523                             When I Think about You      Gloria Tells
# 536  Love Like You (feat. Rebecca Sugar) - End Credits   Steven Universe
# 538                                          messed up           Gabriel
# 547            I Miss My Friends (feat. Phum Viphurit)    Valentina Ploy
# 553                                   First Time Thing         Calabasas
# 554                                      One More Shot               CIL
# 558                                        Nice & Slow        Song House
# 559                                 Just The Two Of Us       Stacey Ryan
# 578                                             Bitter       Michal Leah
#
#                          id genres  \
# 1    44uCMdE6RWnkOFYTtbmUUc    NaN
# 7    6InVPJLNbia2XBqDUVqxWy    NaN
# 8    4Hpi2QkO0Yl8OzirZuyY57    NaN
# 10   3iVPKtYKLeW3PgI2w0fHM1    NaN
# 15   5uMyjSSewg4B9DLXkEHNCo    NaN
# 19   3CM9A4BxQa0WjAOleeyvoh    NaN
# 28   6bWl8yJncLECMCfu5InGOk    NaN
# 29   7rm8f8PBmvAGsa9GfJqga1    NaN
# 34   4wFzDwH40XrQL067ETa9wy    NaN
# 39   2twbMJ7Z0FGUCxEa6qjYEi    NaN
# 42   2jjuzjDbmVOI7kNCSxy5e4    NaN
# 54   6zeS1N6ls8cG4TMablZtFu    NaN
# 93   2dTt16doBXHwu8NEsA6BTx    NaN
# 98   7nMdJr21DRXlIviuRfsAFq    NaN
# 106  3FIsKkmSyjYzLomoR9TWB1    NaN
# 128  6yXc6lrQtoaSX4EeqquXVL    NaN
# 164  41OVfOtiZX9qDiU89r7Nd7    NaN
# 195  2bbG9OmvZLCsdWoRu7rj2m    NaN
# 221  4myLQHREgo0Lca0wBSA85c    NaN
# 262  5uBlr2RNpuu3n7ROgiQa7w    NaN
# 277  6uSHO11NQkKABSvfjc3VVS    NaN
# 294  1Nru7nCQ9VyqaEAez3nKmN    NaN
# 315  2yCT259s8awbxVuW9bBS31    NaN
# 317  2a6UutNdFDE1tKpZU7zyWN    NaN
# 323  7MTrzWI05xnnlc76bi7UdZ    NaN
# 338  69HvmK75WgBbmh6aJsz84U    NaN
# 364  3YvAFDgDpWIfjSPxlw12He    NaN
# 367  0Y4xg5612xZ3vAgWEkMjw3    NaN
# 373  3VEltwNocXM7dVGSdkAs7A    NaN
# 398  09hLpQRURHahZf6JyprZQ4    NaN
# 406  2ul8NCKoRZ8OlLdDdCIRR5    NaN
# 411  4dNwzB7yuTf8jSYZSlok7C    NaN
# 422  5JIkpWBTRbDUacnjHeBwt9    NaN
# 428  7J0bIoaEzZ4rwTyzXryoBk    NaN
# 441  3hxIUxnT27p5WcmjGUXNwx    NaN
# 442  14QUJhbXCWO90NfZ0mXnGG    NaN
# 454  2fHOiCZWlGwLCEJx1Mpn3z    NaN
# 478  0PKAijroHpnEtdY20bkGdr    NaN
# 481  1VgPQTiQKj9baILY8qm5Nv    NaN
# 486  3I7Ojs806okVaVl045FkSu    NaN
# 491  41pmDwHHK9rvdvp6sezqaf    NaN
# 500  2T9MK0ZLDHEcokAPQ2LOv6    NaN
# 502  61jCFoNIuzQnc9UovuzNVW    NaN
# 509  427JUJckVwkdx0susZPzjh    NaN
# 523  038yT5tqY1Fl6kYAbz8wCN    NaN
# 536  3z9OnsnvM6SFN2dzrSDdVO    NaN
# 538  6vwvaxfdzSUpUcnOxPTpMK    NaN
# 547  6CqB5fiJw1yKnytkAPprxr    NaN
# 553  3JlWBPFE8wy4tUrOz6GWEE    NaN
# 554  79uXvsyNG97zMLLq4bloRa    NaN
# 558  4AdfWijz3VBCZ8Ics03ojl    NaN
# 559  4jz3eqH3Y8j565cUe3aSOq    NaN
# 578  68RVDDwyhB281xX5bdYPJH    NaN
#
#                                         album_name  danceability  energy  key  \
# 1                                      Cherry Cola         0.777   0.635    5
# 7                                        Sunkissed         0.701   0.340   11
# 8                                           Ocean~         0.926   0.521    5
# 10                           Don't Lose Your Faith         0.640   0.513    4
# 15                            Anti Love Love Songs         0.708   0.562    8
# 19                                          Fuck U         0.725   0.560    4
# 28                  Satisfied (feat. Travis Mills)         0.839   0.564    9
# 29                                          Jakubi         0.798   0.655    7
# 34                                    Couch Potato         0.736   0.707    8
# 39                                       61 Barkly         0.778   0.581    0
# 42                        Dance in the Living Room         0.758   0.684    6
# 54                     Who's Got You Singing Again         0.830   0.501    0
# 93                                       Starlight         0.722   0.838    3
# 98                   불과 얼음 사이 (feat. Hovi, DJ TOM)         0.752   0.447    4
# 106                           Breathing Underwater         0.411   0.628    6
# 128                                       B.O.M.O.         0.504   0.605    7
# 164                                           Iroh         0.572   0.573    0
# 195                                    Runaway Man         0.755   0.520    3
# 221                                          I did         0.395   0.552    4
# 262                                       dramatic         0.770   0.519    2
# 277                                      After All         0.878   0.475   10
# 294                                    WasteUrTime         0.751   0.529   11
# 315                                      Real Deal         0.433   0.324    8
# 317                                   Bursley Girl         0.441   0.454    1
# 323                                        On Lock         0.660   0.218    0
# 338                                     semilucent         0.546   0.285    0
# 364                                    Lay It Down         0.609   0.826    3
# 367                                       Far Away         0.768   0.519    5
# 373                                           slip         0.728   0.362   11
# 398              I Don't Mind (feat. Ben Chandler)         0.614   0.723    6
# 406                                     Boys Girls         0.710   0.515    7
# 411                Restoration of an American Idol         0.745   0.668    1
# 422                                Time Goes "Bye"         0.645   0.261    4
# 428                                        No Lies         0.735   0.385    7
# 441                        Shut up My Moms Calling         0.485   0.409    9
# 442                                       PINCH ME         0.777   0.465    6
# 454                                          Pills         0.744   0.318   10
# 478                        ghost town (voice memo)         0.471   0.229    8
# 481                                  Perfect Storm         0.844   0.448   10
# 486                              Train of Thoughts         0.490   0.511    2
# 491                                  Oxford Circus         0.418   0.370    1
# 500                                     Love Birds         0.582   0.541    6
# 502                                     Voodoo Blu         0.725   0.543    6
# 509                                   Becky's Plan         0.716   0.854   10
# 523                                 Fly Back to Me         0.743   0.559    8
# 536  Steven Universe, Vol. 1 (Original Soundtrack)         0.591   0.242    0
# 538                                      unfolding         0.832   0.413    6
# 547        I Miss My Friends (feat. Phum Viphurit)         0.457   0.398   10
# 553                               First Time Thing         0.753   0.674   10
# 554                                  One More Shot         0.765   0.435    8
# 558                                    Nice & Slow         0.332   0.503    6
# 559                             Just The Two Of Us         0.563   0.112    8
# 578                                         Bitter         0.805   0.481   10
#
#      loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 1      -6.323     0       0.0392       0.76400          0.000002    0.1550
# 7     -11.057     1       0.1520       0.38600          0.014100    0.2590
# 8      -5.170     0       0.0408       0.46200          0.000117    0.1080
# 10     -6.811     0       0.0420       0.17100          0.000000    0.1010
# 15     -4.592     0       0.0824       0.05340          0.000000    0.1180
# 19     -8.610     0       0.0417       0.11200          0.000221    0.1640
# 28     -5.461     0       0.1810       0.10200          0.000000    0.1100
# 29     -4.805     0       0.0550       0.08470          0.000000    0.0502
# 34     -4.491     1       0.1030       0.25100          0.000000    0.4110
# 39     -5.926     1       0.1000       0.03850          0.000000    0.0268
# 42     -5.037     0       0.0850       0.09530          0.000002    0.1490
# 54     -6.223     1       0.0308       0.53200          0.001300    0.0985
# 93     -3.880     0       0.1330       0.25200          0.000010    0.1790
# 98     -7.601     0       0.0644       0.69500          0.000054    0.1050
# 106    -7.365     0       0.3140       0.60500          0.000000    0.9370
# 128    -6.597     1       0.1250       0.43700          0.000000    0.1780
# 164   -10.958     1       0.0452       0.31900          0.812000    0.0733
# 195    -5.078     1       0.0285       0.71500          0.000000    0.0956
# 221    -4.617     1       0.0459       0.82100          0.000000    0.1060
# 262    -8.482     1       0.0602       0.33200          0.000078    0.1030
# 277    -5.839     1       0.0846       0.26800          0.000000    0.0769
# 294    -8.061     0       0.2180       0.04790          0.000000    0.1050
# 315   -10.520     1       0.1520       0.77200          0.000000    0.1100
# 317   -12.219     1       0.4260       0.41500          0.000000    0.2930
# 323   -13.368     1       0.0319       0.83200          0.000932    0.1760
# 338   -10.237     0       0.0339       0.27400          0.109000    0.0768
# 364    -5.847     1       0.0417       0.02570          0.000000    0.0462
# 367    -8.494     1       0.0739       0.40200          0.000000    0.1830
# 373    -9.055     1       0.4090       0.32900          0.000000    0.1740
# 398    -7.908     1       0.0528       0.64900          0.004110    0.1570
# 406    -7.217     1       0.1220       0.00908          0.002940    0.5750
# 411    -8.682     1       0.2870       0.70300          0.000127    0.0907
# 422   -11.578     1       0.0627       0.69600          0.000044    0.1180
# 428   -10.770     1       0.0503       0.72300          0.000000    0.0866
# 441   -10.711     0       0.1010       0.32500          0.000000    0.1030
# 442   -10.550     0       0.0501       0.62100          0.000000    0.0932
# 454   -13.501     1       0.0506       0.80500          0.005680    0.0505
# 478    -6.504     1       0.0358       0.95300          0.000000    0.0909
# 481    -9.582     0       0.2400       0.28600          0.000000    0.0785
# 486    -6.659     0       0.3300       0.19000          0.000000    0.6730
# 491   -10.416     1       0.1040       0.58300          0.007260    0.1320
# 500    -8.760     0       0.0634       0.22100          0.000000    0.0908
# 502    -9.089     1       0.0387       0.28000          0.475000    0.1130
# 509    -4.304     1       0.0677       0.13200          0.000005    0.0616
# 523    -4.369     0       0.0371       0.20900          0.000006    0.2110
# 536   -10.098     0       0.0312       0.87900          0.000000    0.1500
# 538    -7.954     0       0.0806       0.53600          0.000000    0.0941
# 547    -9.049     1       0.0362       0.77200          0.000000    0.3300
# 553    -8.260     1       0.1620       0.44300          0.000004    0.2510
# 554    -6.224     1       0.0381       0.71500          0.000000    0.0784
# 558    -8.358     0       0.2060       0.45200          0.004140    0.3710
# 559   -15.121     1       0.1990       0.90800          0.000000    0.1110
# 578    -7.770     0       0.0368       0.40000          0.000000    0.0805
#
#      valence    tempo  artist_pop  track_pop  duration_ms  time_signature
# 1     0.6530  138.040          47         56       184360               4
# 7     0.6750   79.934          40         31       213000               4
# 8     0.5340  115.403          47         37       185960               4
# 10    0.1150  120.060          42          0       184392               4
# 15    0.7190  108.899          42          8       202585               4
# 19    0.3660   93.020          40         22       170343               4
# 28    0.8530  132.063          42          0       205000               4
# 29    0.7700  105.963          38         29       226367               4
# 34    0.5800   90.078          38         46       195188               4
# 39    0.7010  140.940          38         21       201160               4
# 42    0.7300  109.953          40         45       244540               4
# 54    0.4810  117.999          61          0       264204               4
# 93    0.7300  151.944          47         33       184453               4
# 98    0.4840   97.066           0          0       207884               4
# 106   0.3530  105.063          18          0       217143               4
# 128   0.6610  108.989          49         42       197630               4
# 164   0.0641  180.005          43          0       285333               4
# 195   0.5170   95.047          26         32       189284               4
# 221   0.3170  126.479           0          0       226536               4
# 262   0.5710  127.991          41         53       150200               4
# 277   0.5660  124.977          35         11       320410               4
# 294   0.7650   77.997          48         45       199139               4
# 315   0.4410   99.862          44         41       281250               3
# 317   0.2640   78.801           8         18       254013               1
# 323   0.3650  124.945          25          8       116300               4
# 338   0.1470  120.112          34         29       240000               3
# 364   0.7940   90.360           0          0       193562               4
# 367   0.4520  112.973          46         51       185084               4
# 373   0.7020   84.599          63         58       183125               4
# 398   0.6420  165.055          51          0       117896               4
# 406   0.4620   99.993          36         36       197940               4
# 411   0.3380  127.837          35         47       138960               4
# 422   0.2160  123.742          44         54       261028               3
# 428   0.3390   81.995          36         19       144399               3
# 441   0.3760  138.419          77         85       164571               4
# 442   0.7570  113.003          55         64       179363               4
# 454   0.6090  139.994          49         42       200000               4
# 478   0.3580   68.410          48         60       137250               3
# 481   0.4510   95.998          64         53       143505               4
# 486   0.6810   84.371          42         27       127053               4
# 491   0.2430  179.660          51         64       152020               4
# 500   0.6940  155.029          27         39       199742               4
# 502   0.4150  140.051          52         59       151578               4
# 509   0.9630   87.538          43         45       185485               4
# 523   0.4290   79.981          47         35       203476               4
# 536   0.2920  118.001          70         69       143630               3
# 538   0.5550   98.996          38         26       191733               4
# 547   0.4480  146.114          47         43       223027               4
# 553   0.7590  105.005          52         61       131289               4
# 554   0.5620  109.969          58         69       141184               3
# 558   0.3960  176.784          52         52       147338               3
# 559   0.3050  168.076          70         43       233929               4
# 578   0.7960   94.977          57         41       186000               4

# %%
# counting each genre in column of lists
df_items = df['genres'].str.split(",", expand=True)
print(df_items)
# Out:
#                              0               1     2         3     4     5  \
# 0                    lo-fi rap            None  None      None  None  None
# 1                          NaN            None  None      None  None  None
# 2              indiana hip hop   indie pop rap   pop   pop rap  None  None
# 3                    lo-fi rap            None  None      None  None  None
# 4                    lo-fi rap            None  None      None  None  None
# ..                         ...             ...   ...       ...   ...   ...
# 586               bedroom soul       chill r&b   pop      None  None  None
# 587  canadian contemporary r&b             pop   r&b      None  None  None
# 588                  chill r&b            None  None      None  None  None
# 589           modern indie pop            None  None      None  None  None
# 590                 indie rock     modern rock  None      None  None  None
#
#         6     7     8     9
# 0    None  None  None  None
# 1    None  None  None  None
# 2    None  None  None  None
# 3    None  None  None  None
# 4    None  None  None  None
# ..    ...   ...   ...   ...
# 586  None  None  None  None
# 587  None  None  None  None
# 588  None  None  None  None
# 589  None  None  None  None
# 590  None  None  None  None
#
# [591 rows x 10 columns]

# %%
frequency_count = pd.melt(df_items)['value'].value_counts()
frequency_count.index.name = "genres"
frequency_count = pd.DataFrame(frequency_count).rename(columns={"value":  "frequency_count"})
with pd.option_context("display.max_rows", 1000):
    print(frequency_count)
# Out:
#                                frequency_count
# genres
#  pop                                       169
# chill r&b                                   72
#  indie r&b                                  70
# alt z                                       46
#  rap                                        41
#  chill r&b                                  40
#  pop rap                                    33
#  r&b                                        31
# bedroom pop                                 31
#  post-teen pop                              30
# bedroom soul                                27
#  electropop                                 26
# lo-fi rap                                   25
# alternative r&b                             24
#  indie pop                                  24
# pop                                         24
#  modern rock                                22
#  dance pop                                  16
#  hip hop                                    15
#  underground hip hop                        15
#  indie poptimism                            15
# indie pop                                   13
# hip hop                                     13
#  indie soul                                 13
#  meme rap                                   12
#  viral rap                                  12
# dance pop                                   11
#  uk pop                                     10
#  gen z singer-songwriter                     9
#  trap                                        9
# modern indie pop                             9
#  lo-fi rap                                   9
# desi hip hop                                 9
#  pop r&b                                     8
# chicago rap                                  8
# canadian contemporary r&b                    8
#  korean r&b                                  8
#  neo mellow                                  8
#  indie pop rap                               8
#  urban contemporary                          7
#  k-pop                                       7
#  indonesian pop                              7
#  bedroom soul                                7
# k-indie                                      7
# asian american hip hop                       7
#  pop rock                                    7
#  vapor twitch                                7
#  uk contemporary r&b                         6
#  social media pop                            6
#  pop dance                                   6
#  neo soul                                    6
# indie r&b                                    6
# indiana hip hop                              6
#  future bass                                 6
#  edm                                         6
#  korean pop                                  6
# edm                                          5
#  vapor soul                                  5
#  modern alternative rock                     5
#  tropical house                              5
#  sad rap                                     5
#  viral pop                                   5
# modern alternative rock                      5
#  pop edm                                     4
#  indietronica                                4
#  hip pop                                     4
#  sad lo-fi                                   4
# indonesian r&b                               4
#  electronic trap                             4
# indonesian lo-fi pop                         4
#  kawaii future bass                          4
# pop rap                                      4
# indie garage rock                            4
#  electro house                               4
# hawaiian hip hop                             4
#  canadian pop                                4
# gen z singer-songwriter                      4
# melodic rap                                  4
#  indonesian singer-songwriter                4
# indie soul                                   4
# la pop                                       4
#  high vibe                                   4
# pop r&b                                      4
# indonesian indie                             4
# boy band                                     4
# bass trap                                    4
#  rock                                        4
#  trap soul                                   4
#  modern indie pop                            4
#  stomp and holler                            3
#  emo rap                                     3
# art pop                                      3
# k-rap                                        3
#  escape room                                 3
#  norwegian indie                             3
# canadian hip hop                             3
# indie pop rap                                3
# alternative pop rock                         3
#  speedrun                                    3
#  bergen indie                                3
#  nyc pop                                     3
#  vgm remix                                   3
#  indie rock                                  3
# indie poptimism                              3
#  hk-pop                                      3
#  bedroom pop                                 3
# hopebeat                                     3
# boston hip hop                               3
#  melodic rap                                 3
# electropop                                   3
# lo-fi beats                                  3
#  hong kong hip hop                           3
# aesthetic rap                                3
# lo-fi chill                                  3
#  pop soul                                    3
# modern rock                                  2
# canadian pop                                 2
#  la pop                                      2
# j-pop                                        2
#  metropopolis                                2
#  lgbtq+ hip hop                              2
# bossbeat                                     2
# hyperpop                                     2
#  pinoy indie                                 2
#  melbourne indie                             2
#  pixel                                       2
#  singaporean pop                             2
# metropopolis                                 2
#  vapor trap                                  2
# pop soul                                     2
# alternative hip hop                          2
# chillhop                                     2
# palestinian hip hop                          2
#  lo-fi beats                                 2
# australian pop                               2
#  scandinavian r&b                            2
#  southern hip hop                            2
# chill pop                                    2
#  nashville indie                             2
#  j-rock                                      2
#  korean trap                                 2
#  bubblegrunge                                2
#  k-rap                                       2
# future bass                                  2
#  trap queen                                  2
# conscious hip hop                            2
# dmv rap                                      2
#  swedish soul                                2
#  la indie                                    2
# k-pop                                        2
#  japanese emo                                2
#  australian alternative pop                  2
# opm                                          2
#  nz pop                                      2
# nyc pop                                      2
#  retro soul                                  2
#  deep new americana                          2
#  visual kei                                  2
# etherpop                                     2
#  indiecoustica                               2
# gangster rap                                 1
# folk-pop                                     1
#  gaming edm                                  1
#  toronto rap                                 1
#  country                                     1
# brostep                                      1
#  filter house                                1
#  southern soul                               1
# leicester indie                              1
#  rhode island rap                            1
# post-teen pop                                1
# pop edm                                      1
#  singaporean electronic                      1
#  vancouver indie                             1
#  australian pop                              1
# deep underground hip hop                     1
# contemporary country                         1
#  armenian hip hop                            1
# austindie                                    1
#  miami hip hop                               1
# japanese r&b                                 1
#  nantes indie                                1
#  toronto indie                               1
#  teen pop                                    1
# irish pop                                    1
# classic soul                                 1
# alberta hip hop                              1
# bronx hip hop                                1
# afrofuturism                                 1
# sad rap                                      1
#  indie surf                                  1
#  indie hip hop                               1
#  fremantle indie                             1
# cali rap                                     1
#  melodic dubstep                             1
# indie psych-pop                              1
#  rap conscient                               1
#  canadian electronic                         1
#  liverpool indie                             1
# underground hip hop                          1
# prog quebec                                  1
# canadian indie                               1
#  uk alternative pop                          1
# singaporean pop                              1
#  modern hard rock                            1
#  funk rj                                     1
# indonesian hip hop                           1
# japanese indie folk                          1
#  alternative r&b                             1
# malaysian pop                                1
#  pop nacional                                1
#  japanese soundtrack                         1
# irish hip hop                                1
#  dreamo                                      1
#  new americana                               1
# british alternative rock                     1
#  queens hip hop                              1
# contemporary r&b                             1
#  pagode baiano                               1
#  punk blues                                  1
#  kentucky hip hop                            1
# dfw rap                                      1
#  east coast hip hop                          1
#  perth indie                                 1
#  dmv rap                                     1
#  hardcore hip hop                            1
#  gangster rap                                1
# memphis hip hop                              1
# british soul                                 1
# barbadian pop                                1
#  chicago rap                                 1
#  progressive electro house                   1
#  norwegian pop                               1
#  minneapolis indie                           1
# australian hip hop                           1
#  malang indie                                1
#  electronica                                 1
#  memphis soul                                1
# emo rap                                      1
# dark pop                                     1
#  trip hop                                    1
#  indie folk                                  1
#  dutch r&b                                   1
# viral pop                                    1
# florida drill                                1
# atl hip hop                                  1
# boston folk                                  1
#  indonesian indie pop                        1
# australian indie                             1
#  pinoy hip hop                               1
#  korean city pop                             1
# funk pop                                     1
# r&b                                          1
#  gauze pop                                   1
#  sudanese pop                                1
#  lo-fi chill                                 1
# anime score                                  1
# viral rap                                    1
#  tagalog rap                                 1
# dutch r&b                                    1
#  pinoy city pop                              1
# nyc rap                                      1
#  florida rap                                 1
#  korean indie folk                           1
#  trap latino                                 1
#  shimmer psych                               1
# indie hip hop                                1
#  laboratorio                                 1
#  soul                                        1
# newcastle nsw indie                          1
#  drill                                       1
#  sudanese hip hop                            1
# uk contemporary r&b                          1
# indie rock                                   1
#  shimmer pop                                 1
#  indonesian r&b                              1
#  vapor pop                                   1
# electra                                      1
#  canadian trap                               1
# indie electropop                             1
#  indie anthem-folk                           1
#  indie electropop                            1
#  little rock indie                           1
# baltimore indie                              1
# ann arbor indie                              1
#  miami indie                                 1
#  swedish alternative rock                    1
#  dream pop                                   1
#  modern dream pop                            1
# brockton hip hop                             1
# complextro                                   1

# %% [markdown]
# We observe 279 unique genres in our playlist of 539 songs. Since most of the genres column consists of lists, we can assume that most of these are subgenres. For the sake of simplicity and because our analysis isn't focused heavily on our genres variable, we will bin these into broader categories.

# %%
# fill missing data in genre column with mode
df['genres'].fillna('pop', inplace = True)

# %%
# double check for any more missing data
df.isnull().sum()
# Out:
# track_name          0
# artist_name         0
# id                  0
# genres              0
# album_name          0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# artist_pop          0
# track_pop           0
# duration_ms         0
# time_signature      0
# dtype: int64

# %%
df.head()
# Out:
#                                           track_name artist_name  \
# 0                                             Lately    Forrest.
# 1                                        Cherry Cola      Kuwada
# 2  A Song to Sing (feat. Mark Battles & Devvon Te...   Kid Quill
# 3                                                NWA        Ryce
# 4                                         Just Chill    Forrest.
#
#                        id                                        genres  \
# 0  5awvelCGpDQHwgZem0ira9                                     lo-fi rap
# 1  44uCMdE6RWnkOFYTtbmUUc                                           pop
# 2  6vl5ghDnotGACfQy6JDYzY  indiana hip hop, indie pop rap, pop, pop rap
# 3  0rWXN4PLsnNaWDelk2938S                                     lo-fi rap
# 4  3ZNOdspGb2cdossfsUqTjw                                     lo-fi rap
#
#                  album_name  danceability  energy  key  loudness  mode  \
# 0                    Lately         0.718   0.632    0    -4.011     1
# 1               Cherry Cola         0.777   0.635    5    -6.323     0
# 2  The Name Above the Title         0.745   0.741    2    -7.212     1
# 3                       NWA         0.829   0.543    7    -6.886     1
# 4                      Warm         0.700   0.530    4    -6.216     1
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0       0.1450       0.21300          0.000013    0.2830    0.859  160.039
# 1       0.0392       0.76400          0.000002    0.1550    0.653  138.040
# 2       0.1840       0.20900          0.000000    0.5100    0.480   94.002
# 3       0.0486       0.39000          0.156000    0.0988    0.358  101.027
# 4       0.0285       0.00775          0.000894    0.1950    0.505   99.992
#
#    artist_pop  track_pop  duration_ms  time_signature
# 0          58         53       207000               4
# 1          47         56       184360               4
# 2          51          0       185487               4
# 3          46          0        83156               4
# 4          58         35       220482               4

# %%
#df.to_csv('playlist_tracks_features.csv')
